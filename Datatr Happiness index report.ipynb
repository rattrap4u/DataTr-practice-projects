# %% [markdown]
# #  World Happiness Index report

# %% [markdown]
# #####
# This report is generated by United Nations Sustainable Development Solutions Network. It is a foundational text for the UN high level meeting, Well being and Happiness,defining a new economic paradigm, drawing international attention.
# ## From the report of world happiness index
# These rankings are accompanied by our latest attempts to show how six key variables contribute to explaining the full sample of national annual average scores over the whole period 2005-2018. These variables are GDP per capita, social support, healthy life expectancy, freedom, generosity, and absence of corruption.
#
# ### Note:-__  That we do not construct our happiness measure in each country using these six factors – the scores are instead based on individuals’ own assessments of their lives, as indicated by the Cantril ladder. Rather, we use the six variables to explain the variation of happiness across countries. We shall also show how measures of experienced well-being, especially positive affect, supplement life circumstances in explaining higher life evaluations.
#
# #### While performing analysis some questions has to be answered:
# 1. Which country is the happiest in the world?
# 2. What are the most important contributing factors to a nation's happiness?
# 3. Is overall happiness incresing or decreasing?

# %%
# importing the required libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\tusha\Downloads\happiness_score_dataset.csv')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# .head() function will show the details of the top 5 happiest countries.
# As it can be observed from the dataset that Switzerland,Iceland,Denmark,Norway and Canada are the top happiest countries.

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
# .tail()  function will show the details of the last 5 countires.

# %%
pd.set_option('display.max_row',None)

# %%
df.info
# Out:
# <bound method DataFrame.info of                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# ...

# %%
# From the output it can be seen that there are 158 rows and 12 columns.
# from table we can observe that Switzerland is at the top with happiness score 7.587
# and togo is at the last place with happiness score 2.839 of the happiness index report.

# %%
df.shape  # it tells the dimension of the dataset.
# Out:
# (158, 12)

# %%
# We have 158 rows and 12 columns in the dataset.

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# As we can see that country and Region are of object datatype, happiness is of integer type datatype and rest all are of float type datatype.

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
# .describe()  show the count, mean ,standard deviation, min maximum,etc
# in this we can also observe that mean and 50% are almost equal.
# count will tell that how many values are there, and it also tells about the missing value, if all the values are not equal.
# it also tell about mean value, standard deviation, minimum and maximum value can also be obtained.
# 50% tell about the median value.


# we can also get the information about the outliers also which is difference between mean and median value.
# from above values it can be observed that there is no outliers.

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# it can be analysed that there is no missing values.

# %%
# it will show all the columns.
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# dropping the columns from the dataset which is of no use in our analysis.
df_1=df.drop(['Standard Error'],axis = 1)

# %%
df_1
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
# checking the null values in the dataset using the heatmap.

plt.figure(figsize=[16,6])
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %%
# After seeing the heatmap we can see that there is no null values.

# %%
# example of univariate analysis

plt.scatter(df_1['Happiness Score'],df_1['Economy (GDP per Capita)'],alpha=0.5,c=(0,0,0),edgecolors='b')
plt.title('Happiness Score vs Economy (GDP per Capita)')
plt.show()
plt.scatter(df_1['Happiness Score'],df_1['Health (Life Expectancy)'],alpha=0.5,c=(0,0,0),edgecolors='g')
plt.title('Happiness Score vs Health (Life Expectancy)')
plt.show()
plt.scatter(df_1['Happiness Score'],df_1['Freedom'],alpha=0.5,c=(0,0,0),edgecolors='r')
plt.title('Happiness Score vs Freedom')
plt.show()
plt.scatter(df_1['Happiness Score'],df_1['Trust (Government Corruption)'],alpha=0.5,c=(0,0,0),edgecolors='b')
plt.title('Happiness Score vs Trust (Government Corruption)')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ### By this scatter plot graph we can say that if Economy (GDP per Capita) increases then Happiness Score also increases, similarly it goes for health, freedom but, it goes other way for Trust (Government Corruption.

# %%
# Bivariate analysis

# %%
corr_mat=df_1.corr()

# %%
corr_mat
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Rank                                -0.785267 -0.733644
# Happiness Score                                0.780966  0.740605
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
plt.figure(figsize=[25,15])
sns.heatmap(corr_mat,annot=True)
plt.title("Correlation Matrix",fontsize=20,fontweight='bold', pad=20)
plt.show()

# %%
# It can be observed for the heatmap that there is a strong relationship between Happiness score and the parameters such as Economy, Family, health, Freedom, Government corruption Generosity .

# %%
# Multivariate analysis

# %%
df_1.plot(kind='density', subplots=True, layout=(6,11), sharex=False, legend=False, fontsize=1, figsize=(25,19))
plt.show()

# %%
# it is an example of multivariate analysis.
# density plot is used to show the distribution of data.
# by seeing the desity plot we can identify there is skewness or not in the data.
# In this plot we have used all the columns.

# %%
# from correlation map we can also analyse that there is a strong relationship betweem Happiness Score,Economy, Family and Health.
# By plotting the cure we can see the relationship.
data_plot = df_1.loc[:,["Health (Life Expectancy)","Family","Economy (GDP per Capita)", "Happiness Score"]]
data_plot.plot()

# %%
# from this graph we can see that the more the economy, the healthier the family the more will be the happiness score.
# as the countries with good economy, the good is the health of the family the more is the happiness score.

# %%
sns.pairplot(df_1)

# %%
# The above plot shows the relationship between various columns in the dataset

# %%
fig,axes=plt.subplots(nrows=2,ncols=2,constrained_layout=True,figsize=(12,8))
sns.barplot(x='Economy (GDP per Capita)',y='Country',data=df.nlargest(10,'Economy (GDP per Capita)'),ax=axes[0,0],palette="Greens_r")
sns.barplot(x='Trust (Government Corruption)' ,y='Country',data=df.nlargest(10,'Trust (Government Corruption)'),ax=axes[0,1],palette="Reds_r")
sns.barplot(x='Health (Life Expectancy)' ,y='Country',data=df.nlargest(10,'Health (Life Expectancy)'),ax=axes[1,0],palette='OrRd')
sns.barplot(x='Freedom' ,y='Country',data=df.nlargest(10,'Freedom'),ax=axes[1,1],palette='YlGnBu_r')

# %%
# from barplot also we can conclude that happiness score increases if econnomy, health, freedom, increases but happiness decreases if corruption increases.

# %%
# applying linear regression method.

from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
x = df_1['Economy (GDP per Capita)'].values.reshape(-1,1)
y = df_1['Happiness Score'].values.reshape(-1,1)

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.5, random_state=0)

lin_reg.fit(x_train,y_train)
y_pred = lin_reg.predict(x_test)
plt.plot(x_test,y_pred)

# %%
# now finding the intercept and coefficient of linear regression equation.
c = lin_reg.intercept_
m = lin_reg.coef_
print('The equation of line is : ',m,'x+',c)
# Out:
# The equation of line is :  [[2.51838997]] x+ [3.32777189]

# %% [markdown]
# ## Conclusion
#
# We have seen in above plots that happiness score increases when GDP per capita, health, family increases.
# Developed countries with greater health facilities, greater family relationship ranked highly in the happiness index.
# deploping countries with less health facilities, less family relationship ranked middle in the happiness index.
# same goes for poor countries they very less GDP, very less health facilities, less family relations ranked very low in the happiness index.
